# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
movies=pd.read_csv("C:/Users/nit/Downloads/AI/Datasets/Movie-Ratings.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns=['Film','Genre','critics_ratings','audience_ratings','budget','year']

# %%
movies.head()
# Out:
#                     Film      Genre  critics_ratings  audience_ratings  \
# 0  (500) Days of Summer      Comedy               87                81
# 1            10,000 B.C.  Adventure                9                44
# 2             12 Rounds      Action               30                52
# 3              127 Hours  Adventure               93                84
# 4              17 Again      Comedy               55                70
#
#    budget  year
# 0       8  2009
# 1     105  2008
# 2      20  2009
# 3      18  2010
# 4      20  2009

# %%
movies.Film=movies.Film.astype("category")

# %%
movies.year=movies.year.astype("category")
movies.Genre=movies.Genre.astype("category")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 6 columns):
# Film                562 non-null category
# Genre               562 non-null category
# critics_ratings     562 non-null int64
# audience_ratings    562 non-null int64
# budget              562 non-null int64
# year                562 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.4 KB

# %%
j=sb.jointplot(data=movies,x='critics_ratings',y='audience_ratings')

# %%
j=sb.jointplot(data=movies,x='critics_ratings',y='audience_ratings',kind='hex')

# %%
m1=sb.distplot(movies.audience_ratings,bins=15)

# %%
n2=plt.hist(movies.critics_ratings,bins=15)

# %%
plt.hist(movies.budget)
# Out:
# (array([239., 163.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 10 Patch objects>)

# %%
filterdrama=movies.Genre=='Drama'

# %%
movies[filterdrama]
# Out:
#                                     Film  Genre  critics_ratings  \
# 10                            88 Minutes  Drama                5
# 11                    A Dangerous Method  Drama               79
# 13                        A Serious Man   Drama               89
# 18                          Albert Nobbs  Drama               53
# 23                       All Good Things  Drama               33
# 26                          An Education  Drama               94
# 27                             Anonymous  Drama               46
# 47                    Black Swan          Drama               88
# 53                             Brothers   Drama               61
# 55                                Buried  Drama               86
# 56                             Burlesque  Drama               36
# 62                            Changeling  Drama               62
# 74                        Country Strong  Drama               20
# ...

# %%
plt.hist(movies[movies.Genre=='Drama'].budget)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].budget)
plt.hist(movies[movies.Genre=='Action'].budget)
plt.hist(movies[movies.Genre=='Thriller'].budget)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].budget,bins=15)
plt.hist(movies[movies.Genre=='Action'].budget,bins=15)
plt.hist(movies[movies.Genre=='Thriller'].budget,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Drama'].budget,
          movies[movies.Genre=='Action'].budget,
          movies[movies.Genre=='Thriller'].budget],bins=15,stacked=True)

plt.show()

# %%
labels=[]
for gen in movies.Genre.cat.categories:
    labels.append(gen)

# %%
list1=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].budget)

# %%
list1
# Out:
# [2       20
#  5      200
#  15      35
#  29      20
#  30      20
#  33     237
#  36      45
#  39      45
#  40      70
#  45     150
#  49      68
#  52      17
#  58     140
#  60      85
#  63      40
#  66     125
#  67      25
#  69      40
#  70      90
#  73      30
#  76     163
#  77      13
#  81      25
#  83      20
#  86      45
#  94      30
#  98      33
#  101     75
#  102     30
#  106     45
#        ...
#  433    138
#  435     50
#  439     40
#  441     80
#  443    150
#  448     25
#  451     40
#  454    145
#  458    100
#  472    150
#  473      6
#  474      0
#  477    100
#  479     75
#  493    150
#  495     35
#  499    150
#  500    195
#  501    210
#  502     30
#  504    170
#  513     35
#  515     95
#  530     75
#  532     25
#  533    130
#  544     35
#  548    150
#  549    160
#  560     24
#  Name: budget, Length: 154, dtype: int64, 1      105
#  3       18
#  19     200
#  21      45
#  24      40
#  32      78
#  46      20
# ...

# %%
plt.hist(list1,bins=15,stacked=True,rwidth=1,label=labels)
plt.show()

# %%
list1.plt.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-b7370ec9c772> in <module>
# ----> 1 list1.plt.hist()
#
# AttributeError: 'list' object has no attribute 'plt'

# %%
list1
# Out:
# [2       20
#  5      200
#  15      35
#  29      20
#  30      20
#  33     237
#  36      45
#  39      45
#  40      70
#  45     150
#  49      68
#  52      17
#  58     140
#  60      85
#  63      40
#  66     125
#  67      25
#  69      40
#  70      90
#  73      30
#  76     163
#  77      13
#  81      25
#  83      20
#  86      45
#  94      30
#  98      33
#  101     75
#  102     30
#  106     45
#        ...
#  433    138
#  435     50
#  439     40
#  441     80
#  443    150
#  448     25
#  451     40
#  454    145
#  458    100
#  472    150
#  473      6
#  474      0
#  477    100
#  479     75
#  493    150
#  495     35
#  499    150
#  500    195
#  501    210
#  502     30
#  504    170
#  513     35
#  515     95
#  530     75
#  532     25
#  533    130
#  544     35
#  548    150
#  549    160
#  560     24
#  Name: budget, Length: 154, dtype: int64, 1      105
#  3       18
#  19     200
#  21      45
#  24      40
#  32      78
#  46      20
# ...

# %%
sb.lmplot(data=movies,x='critics_ratings',y='audience_ratings',fit_reg=False,hue='Genre',size=7,aspect=1)
# Out:
# c:\users\nit\appdata\local\programs\python\python37\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
k1=sb.kdeplot(movies.critics_ratings,movies.audience_ratings,shade=True)

# %%
k1=sb.kdeplot(movies.critics_ratings,movies.audience_ratings,shade=True,shade_lowest=False)

# %%
sb.set_style("dark")
k1=sb.kdeplot(movies.critics_ratings,movies.audience_ratings,shade=True,shade_lowest=False,cmap='Reds')

# %%
x=sb.boxplot(data=movies,x='Genre',y='critics_ratings')

# %%
G=sb.FacetGrid(movies,row='Genre',hue='Genre')

# %%
g=sb.FacetGrid(movies,row='Genre',col='Genre',hue='Genre')

# %%
g=sb.FacetGrid(movies,row='Genre',col='Genre',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g.map(plt.scatter,'critics_ratings','audience_ratings',**kws)
g.set(xlim=(0,100),ylim=(0,100 ))
for ax in g.axes.flat:
    ax.plot((20,60),(20,60))
